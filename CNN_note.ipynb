# %%
from IPython.display import Image
Image(filename = 'cell_and_softmax.JPG')

# %%
from IPython.display import Image
Image(filename ='depth_in_conv.JPG')

# %%
Image(filename = 'use_featurepic_to_classify.JPG')
